# %%
from my_xgbclassifier.utils import  *

concatenate_training_datasets()
# Out:
# Processing 1/1.csv
# Processing 1/2.csv
# Processing 1/3.csv
# Processing 1/4.csv
# Processing 1/5.csv
# Processing 1/6.csv
# Processing 1/7.csv
# Processing 1/8.csv
# Processing 1/9.csv
# Processing 1/10.csv
# Processing 2/1.csv
# Processing 2/2.csv
# Processing 2/3.csv
# Processing 2/4.csv
# Processing 2/5.csv
# Processing 2/6.csv
# Processing 2/7.csv
# Processing 2/8.csv
# Processing 2/9.csv
# Processing 2/10.csv
# Processing 3/1.csv
# Processing 3/2.csv
# Processing 3/3.csv
# Processing 3/4.csv
# Processing 3/5.csv
# Processing 3/6.csv
# Processing 3/7.csv
# Processing 3/8.csv
# Processing 3/9.csv
# Processing 3/10.csv
# Processing 4/1.csv
# Processing 4/2.csv
# Processing 4/3.csv
# Processing 4/4.csv
# Processing 4/5.csv
# Processing 4/6.csv
# Processing 4/7.csv
# Processing 4/8.csv
# Processing 4/9.csv
# Processing 4/10.csv
# ...
