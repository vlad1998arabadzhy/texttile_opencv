# %%
from utils.opencv_utils import *
from utils.graph_utils import  *

create_mask(MASK_PATH)
df = extract_all_features(TEST_PATH)
extract_all_features(TEST_PATH)

# %%
create_graph(df["solidity"], "name")

# %%
import cv2
img= "/home/garuda/PycharmProjects/KI_1/notebooks/mask_binary.png"

mask = cv2.imread(img,0)
contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

result= draw_object_numbers(mask, contours)

cv2.imwrite("enumarated_mask.png", result)

# %%
from  utils.skimage_utils import  *
import cv2

# %%
from utils.opencv_utils import *
from utils.graph_utils import  *

path = "/home/garuda/PycharmProjects/KI_1/pixels/1/1.2.png"

label_image(path)
