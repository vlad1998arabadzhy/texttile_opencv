# %%
from functions.skimage_utils import  *

# %%
path = "/home/garuda/PycharmProjects/KI_1/pixels/1/1.5.png"

extract_features(path)
# Out:
#      label    area  perimeter  solidity
# 0        1   85.24       6.35  0.848841
# 1        2   83.69       5.96  0.871597
# 2        3   61.19       7.56  0.758996
# 3        4   36.97       7.55  0.710305
# 4        5   46.92       8.38  0.735979
# ..     ...     ...        ...       ...
# 107    108  104.28       6.01  0.904212
# 108    109   90.93       5.75  0.918868
# 109    110   81.85       5.71  0.881082
# 110    111   86.98       5.43  0.904420
# 111    112   67.75       4.86  0.894256
#
# [112 rows x 4 columns]
