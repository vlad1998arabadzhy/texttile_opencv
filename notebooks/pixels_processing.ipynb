# %%
from utils.area_calculation import  *

# %%
print(paths)

# %%
create_all_csv()
# Out:
# Processing folder 1 : /home/garuda/PycharmProjects/KI_1/pixels/1
# Document /home/garuda/PycharmProjects/KI_1/pixels/1_updated.csv created
# Processing folder 2 : /home/garuda/PycharmProjects/KI_1/pixels/2
# Document /home/garuda/PycharmProjects/KI_1/pixels/2_updated.csv created
# Processing folder 3 : /home/garuda/PycharmProjects/KI_1/pixels/3
# Document /home/garuda/PycharmProjects/KI_1/pixels/3_updated.csv created
# Processing folder 4 : /home/garuda/PycharmProjects/KI_1/pixels/4
# Document /home/garuda/PycharmProjects/KI_1/pixels/4_updated.csv created
# Processing folder 5 : /home/garuda/PycharmProjects/KI_1/pixels/5
# Document /home/garuda/PycharmProjects/KI_1/pixels/5_updated.csv created
# Processing folder 6 : /home/garuda/PycharmProjects/KI_1/pixels/6
# Document /home/garuda/PycharmProjects/KI_1/pixels/6_updated.csv created
# Processing folder 7 : /home/garuda/PycharmProjects/KI_1/pixels/7
# Document /home/garuda/PycharmProjects/KI_1/pixels/7_updated.csv created
# ...

# %%
print(paths)
