# %%
from functions.skimage_utils import  *


path = "/home/garuda/PycharmProjects/KI_1/pixels/4/4.4.png"
extract_features(path)
# Out:
#     label     area  perimeter  solidity  corners  area_size  size_normalized  \
# 0       1   168.86      22.18  0.652758       86         40         6.257500
# 1       2    87.13       9.73  0.654753       37         40         3.228750
# 2       3    16.39       4.23  0.657645       13         40         0.607500
# 3       4   462.49      26.14  0.870895      106         40        17.138125
# 4       5    19.87       4.95  0.655172       17         40         0.736250
# 5       6  2660.51      45.69  0.855536      174         40        98.588750
# 6       7  1375.07      23.15  0.934976       74         40        50.955000
# 7       8    40.85       4.92  0.752875       25         40         1.513750
# 8       9  1040.38      20.81  0.928067       80         40        38.552500
# 9      10  1245.23      22.24  0.932786       73         40        46.143750
# 10     11  1467.60      24.56  0.925297       75         40        54.383750
# ...

# %%
from functions.skimage_utils import  *
path = "/home/garuda/PycharmProjects/KI_1/pixels/1/1.1.png"
add_size_modified(path)
# Out:
# 1/1.1
# 10
