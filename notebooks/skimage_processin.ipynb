# %%
from functions.check_df import *
from functions.skimage_utils import  *


path = "/home/garuda/PycharmProjects/KI_1/pixels/1/1.1.png"
extract_features(path, None)

# %%
from functions.skimage_utils import  *
path = "/home/garuda/PycharmProjects/KI_1/pixels/1/1.1.png"
add_size_modified(path)
# Out:
# Error occured
# You still have only one class. Gradient Boosting Classifier requires at least two
# 1/1.1
# 10

# %%
traverse_datafolder()
# Out:
# /home/garuda/PycharmProjects/KI_1/pixels/1
# /home/garuda/PycharmProjects/KI_1/functions/skimage_utils.py:193: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, extract_features(path + f"/{file}")], ignore_index=True)
# /home/garuda/PycharmProjects/KI_1/pixels/3
# /home/garuda/PycharmProjects/KI_1/functions/skimage_utils.py:193: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, extract_features(path + f"/{file}")], ignore_index=True)
# /home/garuda/PycharmProjects/KI_1/pixels/4
# /home/garuda/PycharmProjects/KI_1/functions/skimage_utils.py:193: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, extract_features(path + f"/{file}")], ignore_index=True)
# /home/garuda/PycharmProjects/KI_1/pixels/5
# /home/garuda/PycharmProjects/KI_1/functions/skimage_utils.py:193: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, extract_features(path + f"/{file}")], ignore_index=True)
# /home/garuda/PycharmProjects/KI_1/pixels/6
# /home/garuda/PycharmProjects/KI_1/functions/skimage_utils.py:193: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, extract_features(path + f"/{file}")], ignore_index=True)
# /home/garuda/PycharmProjects/KI_1/pixels/7
# /home/garuda/PycharmProjects/KI_1/functions/skimage_utils.py:193: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, extract_features(path + f"/{file}")], ignore_index=True)
# /home/garuda/PycharmProjects/KI_1/pixels/8
# /home/garuda/PycharmProjects/KI_1/functions/skimage_utils.py:193: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, extract_features(path + f"/{file}")], ignore_index=True)
# /home/garuda/PycharmProjects/KI_1/pixels/9
# /home/garuda/PycharmProjects/KI_1/functions/skimage_utils.py:193: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, extract_features(path + f"/{file}")], ignore_index=True)
# /home/garuda/PycharmProjects/KI_1/pixels/10
# /home/garuda/PycharmProjects/KI_1/functions/skimage_utils.py:193: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, extract_features(path + f"/{file}")], ignore_index=True)
# /home/garuda/PycharmProjects/KI_1/pixels/2
# /home/garuda/PycharmProjects/KI_1/functions/skimage_utils.py:193: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, extract_features(path + f"/{file}")], ignore_index=True)
