# %%
from functions.area_stat import *

row_names =[f"{x}x{x}" for x in range(1,11)]

file_names= [f"/home/garuda/PycharmProjects/KI_1/area_sets/{x}_updated.csv" for x in range(1,11)]

# %%
final_df = process_all(file_names, row_names)
to_final_df(final_df, FINAL_PATH)
# Out:
# Processing /home/garuda/PycharmProjects/KI_1/datasets/1_updated.csv
# Index(['Area mm^2', 'Index'], dtype='object')
# Processing /home/garuda/PycharmProjects/KI_1/datasets/2_updated.csv
# Index(['Area mm^2', 'Index'], dtype='object')
# Processing /home/garuda/PycharmProjects/KI_1/datasets/3_updated.csv
# Index(['Area mm^2', 'Index'], dtype='object')
# Processing /home/garuda/PycharmProjects/KI_1/datasets/4_updated.csv
# Index(['Area mm^2', 'Index'], dtype='object')
# Processing /home/garuda/PycharmProjects/KI_1/datasets/5_updated.csv
# Index(['Area mm^2', 'Index'], dtype='object')
# Processing /home/garuda/PycharmProjects/KI_1/datasets/6_updated.csv
# Index(['Area mm^2', 'Index'], dtype='object')
# Processing /home/garuda/PycharmProjects/KI_1/datasets/7_updated.csv
# Index(['Area mm^2', 'Index'], dtype='object')
# Processing /home/garuda/PycharmProjects/KI_1/datasets/8_updated.csv
# Index(['Area mm^2', 'Index'], dtype='object')
# Processing /home/garuda/PycharmProjects/KI_1/datasets/9_updated.csv
# Index(['Area mm^2', 'Index'], dtype='object')
# Processing /home/garuda/PycharmProjects/KI_1/datasets/10_updated.csv
# Index(['Area mm^2', 'Index'], dtype='object')
