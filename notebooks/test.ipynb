# %%
import pandas as pd
import numpy as np
from main import *

row_names =[f"{x}x{x}" for x in range(1,11)]

file_names= [f"/home/garuda/PycharmProjects/KI_1/datasets/Sample group {x}.xlsx" for x in range(1,11)]

# %%
df = concat_datasets("/home/garuda/PycharmProjects/KI_1/datasets/Sample group 7.xlsx")
ls = create_row(df, "7x7")
print(ls)
# Out:
# ['7x7', 192, 1927.02, 1524.91, '1927.02±1524.91', 0.79]

# %%
create_plot(df)

# %%
final_df = process_all(file_names, row_names)
# Out:
# Processing /home/garuda/PycharmProjects/KI_1/datasets/Sample group 2.xlsx
# Processing /home/garuda/PycharmProjects/KI_1/datasets/Sample group 3.xlsx
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/KI_1/lib/python3.12/site-packages/pandas/core/nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#
# File ~/anaconda3/envs/KI_1/lib/python3.12/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# ...
