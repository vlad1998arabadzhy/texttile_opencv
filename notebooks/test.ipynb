# %%
from functions.area_stat import *

row_names =[f"{x}x{x}" for x in range(1,11)]

file_names= [f"/home/garuda/PycharmProjects/KI_1/processed_img_features/{x}.csv" for x in range(1,11)]

# %%
columns = COLUMNS_AREA

to_final_df_csv(names=file_names,rows=row_names, final_path=FINAL_PATH, columns=columns, target_feature='area')
# Out:
# Start to process all .csv files
# Processing /home/garuda/PycharmProjects/KI_1/processed_img_features/1.csv
# Index(['label', 'area', 'perimeter', 'solidity', 'corners', 'area_size',
#        'size_normalized', 'corners_normalized', 'width', 'height',
#        'perfect_area', 'width_to_height_ratio', 'area_normalized'],
#       dtype='object')
# Processing /home/garuda/PycharmProjects/KI_1/processed_img_features/2.csv
# Index(['label', 'area', 'perimeter', 'solidity', 'corners', 'area_size',
#        'size_normalized', 'corners_normalized', 'width', 'height',
#        'perfect_area', 'width_to_height_ratio', 'area_normalized'],
#       dtype='object')
# Processing /home/garuda/PycharmProjects/KI_1/processed_img_features/3.csv
# Index(['label', 'area', 'perimeter', 'solidity', 'corners', 'area_size',
#        'size_normalized', 'corners_normalized', 'width', 'height',
#        'perfect_area', 'width_to_height_ratio', 'area_normalized'],
#       dtype='object')
# ...
